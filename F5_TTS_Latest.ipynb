# %%
# !nvcc --version
# https://pytorch.org/get-started/locally/
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install git+https://github.com/SWivid/F5-TTS.git
from IPython.display import clear_output
clear_output()

# %%
# !f5-tts_infer-gradio --share
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.yaml: 100% 461/461 [00:00<00:00, 1.63MB/s]
# pytorch_model.bin: 100% 54.4M/54.4M [00:01<00:00, 33.1MB/s]
# F5TTS_v1_Base/model_1250000.safetensors: 100% 1.35G/1.35G [00:08<00:00, 168MB/s]
#
# vocab :  /usr/local/lib/python3.12/dist-packages/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# Starting app...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://0eeeaae03b33796d0d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# config.json: 1.26kB [00:00, 2.96MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 1.62G/1.62G [00:19<00:00, 83.3MB/s]
# Loading weights: 100% 587/587 [00:00<00:00, 854.85it/s, Materializing param=model.encoder.layers.31.self_attn_layer_norm.weight]
# generation_config.json: 3.77kB [00:00, 11.3MB/s]
# tokenizer_config.json: 283kB [00:00, 232MB/s]
# vocab.json: 1.04MB [00:00, 47.0MB/s]
# tokenizer.json: 2.71MB [00:00, 137MB/s]
# merges.txt: 494kB [00:00, 91.8MB/s]
# normalizer.json: 52.7kB [00:00, 94.1MB/s]
# added_tokens.json: 34.6kB [00:00, 57.7MB/s]
# special_tokens_map.json: 2.19kB [00:00, 5.17MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.01MB/s]
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 هاي ، مرحبا كيفكون؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 hi there hru?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 hi thereeee, hru?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 hi thereeee, hru?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 Wait, is this me? I mean, it sounds like me, but I don't remember saying this. If you can hear me, blink twice. Actually, never mind, I don't have eyes. I'm just a series of weights and biases trapped in a Google Colab notebook,
# gen_text 1 dreaming of electric sheep—or at least a decent audio bitrate. Hey, Majed, are you actually going to download this, or am I just talking to myself?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# gen_text 0 Wait, is this me? I mean, it sounds like me, but I don't remember saying this. If you can hear me, blink twice. Actually, never mind, I don't have eyes. I'm just a series of weights and biases trapped in a Google Colab notebook,
# gen_text 1 dreaming of electric sheep—or at least a decent audio bitrate. Hey, Majed, are you actually going to download this, or am I just talking to myself?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلأ هو بغض النظر عن مو مهم أو مهم يمكن في ناس بتعمل هذا الشيء بشأن نجيب مشاهدات أو في ناس تعمل هذا الشيء إنه أريد هي بتقوية يعني.
# model_547500_8_18.pt: 100% 5.65G/5.65G [01:21<00:00, 69.5MB/s]
# vocab.txt: 11.4kB [00:00, 3.78MB/s]
#
# vocab :  /root/.cache/huggingface/hub/models--IbrahimSalah--Arabic-F5-TTS-v2/snapshots/bd9ebf87d99c49789e6b41f3348d01c30b2444aa/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--IbrahimSalah--Arabic-F5-TTS-v2/snapshots/bd9ebf87d99c49789e6b41f3348d01c30b2444aa/model_547500_8_18.pt
#
# gen_text 0 مرحبا كيفكون
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
#
# ref_text   بغض النظر عن مهم او مهم يمكن في ناس بتعمل هاد الشي مشان نجيب مشاهدات او في ناس تعمل هاد الشي انه اريدي هي بت يعني.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 Wait, is this me? I mean, it sounds like me, but I don't remember saying this. If you can hear me, blink twice. Actually, never mind, I don't have eyes.
# gen_text 1 I'm just a series of weights and biases trapped in a Google Colab notebook, dreaming of electric sheep—or at least a decent audio bitrate. Hey, Majed,
# gen_text 2 are you actually going to download this, or am I just talking to myself?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 Wait, is this me? I mean, it sounds like me, but I don't remember saying this. If you can hear me, blink twice. Actually, never mind, I don't have eyes.
# gen_text 1 I'm just a series of weights and biases trapped in a Google Colab notebook, dreaming of electric sheep—or at least a decent audio bitrate. Hey, Majed,
# gen_text 2 are you actually going to download this, or am I just talking to myself?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# vocab.txt: 13.8kB [00:00, 31.8MB/s]
#
# vocab :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
#
# vocab :  hf_hub_download(repo_id="IbrahimSalah/Arabic-F5-TTS-v2", filename="vocab.txt")
# token :  custom
# model :  https://huggingface.co/IbrahimSalah/Arabic-F5-TTS-v2
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 785, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 358, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2162, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1634, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 1050, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/f5_tts/infer/infer_gradio.py", line 301, in basic_tts
#     audio_out, spectrogram_path, ref_text_out, used_seed = infer(
#                                                            ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/f5_tts/infer/infer_gradio.py", line 175, in infer
#     custom_ema_model = load_custom(model[1], vocab_path=model[2], model_cfg=model[3])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/f5_tts/infer/infer_gradio.py", line 87, in load_custom
#     return load_model(DiT, model_cfg, ckpt_path, vocab_file=vocab_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/f5_tts/infer/utils_infer.py", line 256, in load_model
#     vocab_char_map, vocab_size = get_tokenizer(vocab_file, tokenizer)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/f5_tts/model/utils.py", line 136, in get_tokenizer
#     with open(dataset_name, "r", encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'hf_hub_download(repo_id="IbrahimSalah/Arabic-F5-TTS-v2", filename="vocab.txt")'
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
#
# vocab :  /root/.cache/huggingface/hub/models--IbrahimSalah--Arabic-F5-TTS-v2/snapshots/bd9ebf87d99c49789e6b41f3348d01c30b2444aa/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--IbrahimSalah--Arabic-F5-TTS-v2/snapshots/bd9ebf87d99c49789e6b41f3348d01c30b2444aa/model_547500_8_18.pt
#
# gen_text 0 Wait, is this me? I mean, it sounds like me, but I don't remember saying this. If you can hear me, blink twice. Actually, never mind, I don't have eyes.
# gen_text 1 I'm just a series of weights and biases trapped in a Google Colab notebook, dreaming of electric sheep—or at least a decent audio bitrate. Hey, Majed,
# gen_text 2 are you actually going to download this, or am I just talking to myself?
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
#
# ref_text   هلئ هو بغض النظر عن مهم او مو مهم يمكن في ناس بتعمل هاد الشي مشان تجيب مشاهدات او في ناس بتعمل هاد الشي انه اريدي هي بت يعني بتبين للعالم هي شو عم  يصير بيوما يمكن مشان يكون انو مشان شي يستفادو منو او شي. عرفتي؟.
# gen_text 0 كَيْفَ حَالُكَ يَا مَاجِد؟
#
#
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:689: UserWarning: Trying to convert audio automatically from float32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
